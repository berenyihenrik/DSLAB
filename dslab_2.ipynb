# %% [markdown]
# # Setup Environment and Read Data

# %%
import torch
import numpy as np
import pandas as pd
import pickle
import copy
from tqdm import trange,tqdm
import torch.nn as nn
from torch.optim import Adam
from torch.optim.lr_scheduler import ReduceLROnPlateau
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import f1_score, classification_report, confusion_matrix

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
DRIVE = "drive/MyDrive/Colab Notebooks/ELTE/DSLAB/dataset/"
DATASET = DRIVE + "MBD.csv"
TOPOLOGY = DRIVE + "MBD_topology.pk"
NUM_OF_COMPONENTS = 5

data = pd.read_csv(DATASET, header=[0,1])
true_anomalies = data['label'].values

metric = data.drop(['date', 'label'], axis = 1)
metric.columns.names = ['host','metric']
tempm = metric.swaplevel('metric','host',axis=1).stack()
tempm = (tempm-tempm.mean())/(tempm.std())
metric = tempm.unstack().swaplevel('metric','host',axis=1).stack().unstack()
metric_tensor = torch.tensor(metric.values, dtype=torch.float32)

with open(TOPOLOGY, 'rb') as f:
    edge_index = pickle.load(f)
# Out:
# <ipython-input-2-49ccc0f6c925>:9: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   metric = data.drop(['date', 'label'], axis = 1)
# <ipython-input-2-49ccc0f6c925>:11: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   tempm = metric.swaplevel('metric','host',axis=1).stack()
# <ipython-input-2-49ccc0f6c925>:13: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   metric = tempm.unstack().swaplevel('metric','host',axis=1).stack().unstack()

# %%
metric
# Out:
# host              R740-3-1                                               \
# metric cpu.mean_usage_idle cpu.mean_usage_iowait cpu.mean_usage_softirq
# 0                 1.297715             -0.632874              -0.703865
# 1                 1.386064             -0.747534              -0.703948
# 2                -1.239377             -0.797039              -0.664087
# 3                -1.644451             -0.835336              -0.703936
# 4                -1.643598             -0.838276              -0.703845
# ...                    ...                   ...                    ...
# 8635              1.438887             -0.821302              -0.703730
# 8636              1.451945             -0.836429              -0.695918
# 8637              1.440971             -0.827184              -0.672011
# 8638              1.437342             -0.821685              -0.664070
# 8639              1.451885             -0.833846              -0.743528
#
# host                                                                     \
# metric cpu.mean_usage_system cpu.mean_usage_user disk.mean_used_percent
# 0                  -0.812009           -0.960151              -1.912235
# 1                  -0.834344           -0.958793              -1.912233
# 2                  -0.693319            2.380106              -1.912231
# 3                  -0.719389            2.927902              -1.912229
# 4                  -0.687902            2.928635              -1.912227
# ...                      ...                 ...                    ...
# 8635               -0.792337           -0.955754              -1.911606
# 8636               -0.784464           -0.956904              -1.911604
# 8637               -0.832834           -0.950063              -1.911602
# 8638               -0.765072           -0.954403              -1.911601
# 8639               -0.800240           -0.958342              -1.911599
#
# host                                                                  \
# metric diskio.io_time diskio.mean_iops_in_progress diskio.read_speed
# 0           -0.125818                    -0.394307         -0.484756
# 1           -0.149738                    -0.426539         -0.484756
# 2           -0.137616                    -0.426539         -0.483687
# 3           -0.146556                    -0.422957         -0.484743
# 4           -0.174985                    -0.412214         -0.484756
# ...               ...                          ...               ...
# 8635        -0.226616                    -0.462351         -0.484756
# 8636        -0.233937                    -0.462351         -0.484756
# 8637        -0.230273                    -0.462351         -0.484756
# 8638        -0.235003                    -0.462351         -0.484756
# 8639        -0.232342                    -0.462351         -0.484756
#
# host                       ...      R740-3-5                         \
# metric diskio.write_speed  ... mem.mean_free net.recieved  net.sent
# 0               -0.549166  ...     -0.600163    -0.729554  0.131946
# 1               -0.549179  ...     -0.496413    -0.729449  0.131897
# 2               -0.549084  ...     -0.499616    -0.728573  0.131962
# 3               -0.548879  ...     -0.503554    -0.727601  0.957520
# 4               -0.549193  ...     -0.552925    -0.730687  0.133904
# ...                   ...  ...           ...          ...       ...
# 8635            -0.549426  ...     -0.640990     0.278332 -0.135095
# 8636            -0.549877  ...     -0.642823     0.020555 -0.657424
# 8637            -0.549508  ...     -0.625552     0.441609  0.009106
# 8638            -0.548154  ...     -0.654699    -0.484553  0.898695
# 8639            -0.549357  ...     -0.663206    -0.728644  0.732069
#
# host                                                      \
# metric netstat.mean_tcp_time_wait processes.mean_blocked
# 0                        3.001606               0.021189
# 1                        2.956195               1.096132
# 2                        2.570205               0.558660
# 3                        3.818996               1.096132
# 4                        3.773586               0.289925
# ...                           ...                    ...
# 8635                     0.095328              -0.516282
# 8636                    -0.040904              -0.516282
# 8637                    -0.177136              -0.516282
# 8638                    -0.109020              -0.516282
# 8639                    -0.109020              -0.516282
#
# host                                                                  \
# metric processes.mean_running processes.mean_total system.mean_load1
# 0                   -0.109772             0.070849          1.693814
# 1                   -0.109772             0.070849          1.696252
# 2                   -0.109772             0.070849          1.831540
# 3                   -0.109772             0.034244          2.139900
# 4                   -0.109772             0.070849          2.139900
# ...                       ...                  ...               ...
# 8635                -0.109772            -1.027300          0.144702
# 8636                -0.109772            -1.027300          0.153234
# 8637                -0.109772            -1.027300          0.182485
# 8638                -0.109772            -1.027300          0.156890
# 8639                -0.109772            -1.027300          0.206861
#
# host
# metric system.mean_load15 system.mean_load5
# 0                0.910688          1.767932
# 1                0.950638          1.783531
# 2                1.008166          1.843091
# 3                1.088067          1.955121
# 4                1.145595          2.009008
# ...                   ...               ...
# 8635             0.384942          0.030765
# 8636             0.381746          0.047782
# 8637             0.378550          0.067635
# 8638             0.372158          0.077562
# 8639             0.370560          0.098833
#
# [8640 rows x 130 columns]

# %% [markdown]
# # Preprocess the Dataset

# %%
# Scale the values of the input metrics
scaler = MinMaxScaler()
metric_scaled = scaler.fit_transform(metric)
metric_tensor = torch.tensor(metric_scaled, dtype=torch.float32)
metric_scaled = pd.DataFrame(metric_scaled, index=metric.index, columns=metric.columns)
metric_scaled
# Out:
# host              R740-3-1                                               \
# metric cpu.mean_usage_idle cpu.mean_usage_iowait cpu.mean_usage_softirq
# 0                 0.950674              0.196214               0.038462
# 1                 0.977175              0.088424               0.038382
# 2                 0.189643              0.041885               0.077036
# 3                 0.068136              0.005882               0.038393
# 4                 0.068392              0.003118               0.038481
# ...                    ...                   ...                    ...
# 8635              0.993020              0.019076               0.038593
# 8636              0.996937              0.004855               0.046169
# 8637              0.993645              0.013547               0.069352
# 8638              0.992556              0.018716               0.077052
# 8639              0.996919              0.007283               0.000000
#
# host                                                                     \
# metric cpu.mean_usage_system cpu.mean_usage_user disk.mean_used_percent
# 0                   0.003521            0.001633               0.024794
# 1                   0.002268            0.001958               0.024931
# 2                   0.010180            0.799099               0.025091
# 3                   0.008718            0.929881               0.025243
# 4                   0.010484            0.930056               0.025374
# ...                      ...                 ...                    ...
# 8635                0.004625            0.002683               0.070769
# 8636                0.005066            0.002408               0.070892
# 8637                0.002353            0.004042               0.071016
# 8638                0.006154            0.003006               0.071135
# 8639                0.004181            0.002065               0.071258
#
# host                                                                  \
# metric diskio.io_time diskio.mean_iops_in_progress diskio.read_speed
# 0            0.139161                     0.004854          0.000000
# 1            0.109986                     0.002555          0.000000
# 2            0.124771                     0.002555          0.001839
# 3            0.113868                     0.002810          0.000022
# 4            0.079193                     0.003577          0.000000
# ...               ...                          ...               ...
# 8635         0.016220                     0.000000          0.000000
# 8636         0.007291                     0.000000          0.000000
# 8637         0.011761                     0.000000          0.000000
# 8638         0.005991                     0.000000          0.000000
# 8639         0.009237                     0.000000          0.000000
#
# host                       ...      R740-3-5                         \
# metric diskio.write_speed  ... mem.mean_free net.recieved  net.sent
# 0                0.000203  ...      0.026584     0.000183  0.098977
# 1                0.000200  ...      0.055531     0.000192  0.098971
# 2                0.000221  ...      0.054637     0.000267  0.098979
# 3                0.000264  ...      0.053539     0.000350  0.198149
# 4                0.000197  ...      0.039764     0.000086  0.099212
# ...                   ...  ...           ...          ...       ...
# 8635             0.000148  ...      0.015193     0.086387  0.066898
# 8636             0.000052  ...      0.014681     0.064340  0.004154
# 8637             0.000131  ...      0.019500     0.100352  0.084221
# 8638             0.000418  ...      0.011368     0.021138  0.191083
# 8639             0.000163  ...      0.008994     0.000261  0.171067
#
# host                                                      \
# metric netstat.mean_tcp_time_wait processes.mean_blocked
# 0                        0.334012               0.086957
# 1                        0.329939               0.260870
# 2                        0.295316               0.173913
# 3                        0.407332               0.260870
# 4                        0.403259               0.130435
# ...                           ...                    ...
# 8635                     0.073320               0.000000
# 8636                     0.061100               0.000000
# 8637                     0.048880               0.000000
# 8638                     0.054990               0.000000
# 8639                     0.054990               0.000000
#
# host                                                                  \
# metric processes.mean_running processes.mean_total system.mean_load1
# 0                         0.0             0.526316          0.362028
# 1                         0.0             0.526316          0.362323
# 2                         0.0             0.526316          0.378685
# 3                         0.0             0.513158          0.415979
# 4                         0.0             0.526316          0.415979
# ...                       ...                  ...               ...
# 8635                      0.0             0.131579          0.174676
# 8636                      0.0             0.131579          0.175708
# 8637                      0.0             0.131579          0.179245
# 8638                      0.0             0.131579          0.176150
# 8639                      0.0             0.131579          0.182193
#
# host
# metric system.mean_load15 system.mean_load5
# 0                0.459178          0.429102
# 1                0.466216          0.431143
# 2                0.476351          0.438938
# 3                0.490428          0.453601
# 4                0.500563          0.460653
# ...                   ...               ...
# 8635             0.366554          0.201745
# 8636             0.365991          0.203972
# 8637             0.365428          0.206570
# 8638             0.364302          0.207869
# 8639             0.364020          0.210653
#
# [8640 rows x 130 columns]

# %% [markdown]
# ### Scaled

# %%
# create train and test dataloaders
metric_scaled.interpolate(inplace=True)
metric_scaled.bfill(inplace=True)
metric_tensor = metric_scaled.values
sequence_length = 30
sequences = [metric_tensor[i:i + sequence_length].reshape(sequence_length, NUM_OF_COMPONENTS, -1) for i in range(metric_tensor.shape[0] - sequence_length + 1)]

train_data, temp_data = train_test_split(sequences, test_size=0.3, random_state=42) # 70% train, 30% temp
val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42) # 50% of temp for val and test

batch_size = 32
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(dataset=val_data, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Non-Scaled

# %% [markdown]
# Regular

# %%
# create train and test dataloaders
metric.interpolate(inplace=True)
metric.bfill(inplace=True)
metric_tensor = metric.values
sequence_length = 30
sequences = [metric_tensor[i:i + sequence_length].reshape(sequence_length, NUM_OF_COMPONENTS, -1) for i in range(metric_tensor.shape[0] - sequence_length + 1)]

train_data, temp_data = train_test_split(sequences, test_size=0.3, random_state=42) # 70% train, 30% temp
val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42) # 50% of temp for val and test

batch_size = 32
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(dataset=val_data, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
sequences[0].shape
# Out:
# (30, 5, 26)

# %% [markdown]
# LSTM

# %%
# create train and test dataloaders
metric.interpolate(inplace=True)
metric.bfill(inplace=True)
metric_tensor = metric.values
sequence_length = 30
num_metrics = metric_tensor.shape[1] // NUM_OF_COMPONENTS
input_dim = NUM_OF_COMPONENTS * num_metrics

sequences = [metric_tensor[i:i + sequence_length].reshape(sequence_length, input_dim)
             for i in range(metric_tensor.shape[0] - sequence_length + 1)]

train_data, temp_data = train_test_split(sequences, test_size=0.3, random_state=42) # 70% train, 30% temp
val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42) # 50% of temp for val and test

batch_size = 32
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(dataset=val_data, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
sequences[0].shape
# Out:
# (30, 130)

# %% [markdown]
# # Define the Network

# %% [markdown]
# ## Feed forward

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, hidden_dim, latent_dim):
        super(Encoder, self).__init__()

        self.linear1 = nn.Linear(input_dim, hidden_dim)
        self.linear2 = nn.Linear(hidden_dim, hidden_dim)
        self.mean = nn.Linear(hidden_dim, latent_dim)
        self.var = nn.Linear (hidden_dim, latent_dim)
        self.LeakyReLU = nn.LeakyReLU(0.2)
        self.training = True

    def forward(self, x):
        x = self.linear1(x)
        x = self.LeakyReLU(x)
        x = self.linear2(x)
        x = self.LeakyReLU(x)

        mean = self.mean(x)
        log_var = self.var(x)
        return mean, log_var

# %%
class Decoder(nn.Module):
    def __init__(self, output_dim, hidden_dim, latent_dim):
        super(Decoder, self).__init__()

        self.linear2 = nn.Linear(latent_dim, hidden_dim)
        self.linear1 = nn.Linear(hidden_dim, hidden_dim)
        self.output = nn.Linear(hidden_dim, output_dim)
        self.LeakyReLU = nn.LeakyReLU(0.2)

    def forward(self, x):
        x = self.linear2(x)
        x = self.LeakyReLU(x)
        x = self.linear1(x)
        x = self.LeakyReLU(x)

        x_hat = torch.sigmoid(self.output(x))
        return x_hat

# %%
class VAE(nn.Module):
    def __init__(self, input_dim, hidden_dim=200, latent_dim=26, device=device):
        super(VAE, self).__init__()

        self.encoder = Encoder(input_dim, hidden_dim, latent_dim).to(device)
        self.decoder = Decoder(input_dim, hidden_dim, latent_dim).to(device)

    def reparameterization(self, mean, var):
        epsilon = torch.randn_like(var).to(device)
        z = mean + var*epsilon
        return z

    def forward(self, x):
        mean, log_var = self.encoder(x)
        z = self.reparameterization(mean, torch.exp(0.5 * log_var))
        x_hat = self.decoder(z)
        return x_hat, mean, log_var

# %%
model = VAE(input_dim=26).to(device)
optimizer = Adam(model.parameters(), lr=1e-3)

# %% [markdown]
# ## LSTM

# %%
class LSTMEncoder(nn.Module):
    def __init__(self, input_dim, hidden_dim, latent_dim, num_layers=1):
        super(LSTMEncoder, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers=num_layers, batch_first=True)
        self.fc_mean = nn.Linear(hidden_dim, latent_dim)
        self.fc_logvar = nn.Linear(hidden_dim, latent_dim)

    def forward(self, x):
        _, (h_n, _) = self.lstm(x)  # h_n: (num_layers, batch, hidden_dim)
        h = h_n[-1]  # take the output of the last layer
        return self.fc_mean(h), self.fc_logvar(h)


class LSTMDecoder(nn.Module):
    def __init__(self, latent_dim, hidden_dim, output_dim, sequence_length, num_layers=1):
        super(LSTMDecoder, self).__init__()
        self.sequence_length = sequence_length
        self.latent_to_hidden = nn.Linear(latent_dim, hidden_dim)
        self.lstm = nn.LSTM(hidden_dim, hidden_dim, num_layers=num_layers, batch_first=True)
        self.output_layer = nn.Linear(hidden_dim, output_dim)

    def forward(self, z):
        # Repeat z for each timestep
        hidden = self.latent_to_hidden(z).unsqueeze(1).repeat(1, self.sequence_length, 1)
        out, _ = self.lstm(hidden)
        return self.output_layer(out)


class LSTMVAE(nn.Module):
    def __init__(self, input_dim, hidden_dim, latent_dim, sequence_length, num_layers=1, device='cpu'):
        super(LSTMVAE, self).__init__()
        self.encoder = LSTMEncoder(input_dim, hidden_dim, latent_dim, num_layers).to(device)
        self.decoder = LSTMDecoder(latent_dim, hidden_dim, input_dim, sequence_length, num_layers).to(device)

    def reparameterize(self, mean, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mean + eps * std

    def forward(self, x):
        mean, logvar = self.encoder(x)
        z = self.reparameterize(mean, logvar)
        x_recon = self.decoder(z)
        return x_recon, mean, logvar

# %%
hidden_dim = 128
latent_dim = 32
num_layers = 1

model = LSTMVAE(input_dim=input_dim,
                hidden_dim=hidden_dim,
                latent_dim=latent_dim,
                sequence_length=sequence_length,
                num_layers=num_layers,
                device=device).to(device)
optimizer = Adam(model.parameters(), lr=1e-3)

# %% [markdown]
# ## Support functions

# %%
def loss_function(x, x_hat, mean, log_var):
    reproduction_loss = nn.functional.mse_loss(x_hat, x, reduction='sum')
    KLD = - 0.5 * torch.sum(1+ log_var - mean.pow(2) - log_var.exp())

    return reproduction_loss + KLD

# %%
def save_model(model):
    model_state = {
        'input_dim':26,
        'latent_dim':26,
        'hidden_dim':200,
        'state_dict':model.state_dict()
    }
    torch.save(model_state,'vae.pth')

# %% [markdown]
# # Train

# %% [markdown]
# ## Feed forward

# %%
torch.cuda.empty_cache()

scheduler = ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.1, verbose=True)

# SPO optimizer - optuna
# bayesian hyperparameter tuning
# grid search - slow for DL

def train_model(model, train_loader, val_loader, optimizer, loss_fn, scheduler, num_epochs=10):
    train_losses = []
    val_losses = []

    early_stop_tolerant_count = 0
    early_stop_tolerant = 10
    best_loss = float('inf')
    for epoch in range(num_epochs):  # loop over the dataset multiple times
        train_loss = 0.0
        model.train()
        for batch_idx, x in enumerate(train_loader):
            x = x.to(device).type(torch.float32)

            # zero the parameter gradients
            optimizer.zero_grad()

            x_hat, mean, log_var = model(x)

            # forward + loss + backward + optimize
            loss = loss_fn(x, x_hat, mean, log_var)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_loss /= len(train_loader)  # Divide by number of batches
        train_losses.append(train_loss)

        # Validation
        model.eval()
        valid_loss = 0.0
        with torch.no_grad():
            for batch_idx, x in enumerate(val_loader):
                x = x.to(device).type(torch.float32)

                x_hat, mean, log_var = model(x)

                loss = loss_fn(x, x_hat, mean, log_var)
                valid_loss += loss.item()

        valid_loss /= len(val_loader)  # Divide by number of batches
        val_losses.append(valid_loss)

        scheduler.step(valid_loss)

        early_stop_tolerant_count += 1
        if valid_loss < best_loss:
            early_stop_tolerant_count = 0
            best_loss = valid_loss
            best_model_wts = copy.deepcopy(model.state_dict())

        if early_stop_tolerant_count >= early_stop_tolerant:
            print("Early stopping triggered")
            break

        print(f"Epoch {epoch:04d}: train loss {train_loss:.4f}, valid loss {valid_loss:.4f}")
        save_model(model)

    print('Finished Training')
    return train_losses, val_losses

train_losses, val_losses = train_model(model, train_loader, val_loader, optimizer, loss_function, scheduler, num_epochs=100)

# %% [markdown]
# ## LSTM

# %%
torch.cuda.empty_cache()

scheduler = ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.1, verbose=True)

# SPO optimizer - optuna
# bayesian hyperparameter tuning
# grid search - slow for DL

def train_model(model, train_loader, val_loader, optimizer, loss_fn, scheduler, num_epochs=10):
    train_losses = []
    val_losses = []

    early_stop_tolerant_count = 0
    early_stop_tolerant = 10
    best_loss = float('inf')
    for epoch in range(num_epochs):  # loop over the dataset multiple times
        train_loss = 0.0
        model.train()
        for batch in train_loader:
            batch = torch.tensor(batch, dtype=torch.float32).to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            recon_batch, mean, logvar = model(batch)

            # forward + loss + backward + optimize
            loss = loss_fn(recon_batch, batch, mean, logvar)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_loss /= len(train_loader)  # Divide by number of batches
        train_losses.append(train_loss)

        # Validation
        model.eval()
        valid_loss = 0.0
        with torch.no_grad():
            for batch in val_loader:
                batch = torch.tensor(batch, dtype=torch.float32).to(device)

                recon_batch, mean, logvar = model(batch)

                loss = loss_fn(recon_batch, batch, mean, logvar)
                valid_loss += loss.item()

        valid_loss /= len(val_loader)  # Divide by number of batches
        val_losses.append(valid_loss)

        scheduler.step(valid_loss)

        early_stop_tolerant_count += 1
        if valid_loss < best_loss:
            early_stop_tolerant_count = 0
            best_loss = valid_loss
            best_model_wts = copy.deepcopy(model.state_dict())

        if early_stop_tolerant_count >= early_stop_tolerant:
            print("Early stopping triggered")
            break

        print(f"Epoch {epoch:04d}: train loss {train_loss:.4f}, valid loss {valid_loss:.4f}")
        save_model(model)

    print('Finished Training')
    return train_losses, val_losses

train_losses, val_losses = train_model(model, train_loader, val_loader, optimizer, loss_function, scheduler, num_epochs=200)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# <ipython-input-11-2be549fea2fb>:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch = torch.tensor(batch, dtype=torch.float32).to(device)
# <ipython-input-11-2be549fea2fb>:41: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch = torch.tensor(batch, dtype=torch.float32).to(device)
# Epoch 0000: train loss 76584.9956, valid loss 63101.6247
# Epoch 0001: train loss 62866.0165, valid loss 54600.2881
# Epoch 0002: train loss 55555.9982, valid loss 49877.1317
# Epoch 0003: train loss 51369.8648, valid loss 47354.2061
# Epoch 0004: train loss 48993.9102, valid loss 43825.0563
# Epoch 0005: train loss 46910.5213, valid loss 43424.4389
# Epoch 0006: train loss 45563.3791, valid loss 41011.7172
# Epoch 0007: train loss 44562.4781, valid loss 39729.2514
# Epoch 0008: train loss 43440.9917, valid loss 39177.5302
# Epoch 0009: train loss 42337.1404, valid loss 37855.2017
# Epoch 0010: train loss 42092.9360, valid loss 36890.5984
# Epoch 0011: train loss 40696.0306, valid loss 36049.2300
# Epoch 0012: train loss 40350.4224, valid loss 36816.3644
# Epoch 0013: train loss 40088.1026, valid loss 35408.3698
# Epoch 0014: train loss 39533.2423, valid loss 34936.5549
# Epoch 0015: train loss 38707.3459, valid loss 34494.4285
# Epoch 0016: train loss 38654.2922, valid loss 34869.8941
# Epoch 0017: train loss 38100.2444, valid loss 33420.3599
# Epoch 0018: train loss 37129.3937, valid loss 33984.3841
# Epoch 0019: train loss 37134.0466, valid loss 32976.9445
# Epoch 0020: train loss 36780.7715, valid loss 32986.8842
# Epoch 0021: train loss 36311.0869, valid loss 32238.7808
# Epoch 0022: train loss 35986.2702, valid loss 31643.3709
# Epoch 0023: train loss 35606.7143, valid loss 31379.7956
# Epoch 0024: train loss 35216.1469, valid loss 32180.2628
# Epoch 0025: train loss 35450.7132, valid loss 31040.7901
# Epoch 0026: train loss 35102.1853, valid loss 31356.4952
# Epoch 0027: train loss 34938.0658, valid loss 30315.1641
# Epoch 0028: train loss 34016.1222, valid loss 30018.2616
# Epoch 0029: train loss 34035.1351, valid loss 30297.4064
# Epoch 0030: train loss 33849.9144, valid loss 29730.9547
# Epoch 0031: train loss 33515.9948, valid loss 29638.6407
# Epoch 0032: train loss 33613.5336, valid loss 29867.4672
# Epoch 0033: train loss 33066.0978, valid loss 28806.7886
# Epoch 0034: train loss 33431.7994, valid loss 29411.0991
# Epoch 0035: train loss 32939.3157, valid loss 28577.6395
# Epoch 0036: train loss 32684.3019, valid loss 28886.6664
# Epoch 0037: train loss 33077.7754, valid loss 29245.4621
# Epoch 0038: train loss 32401.1012, valid loss 28563.9755
# Epoch 0039: train loss 32415.1505, valid loss 28667.5519
# Epoch 0040: train loss 31925.6731, valid loss 28661.9244
# Epoch 0041: train loss 31873.1593, valid loss 27905.8599
# Epoch 0042: train loss 31788.2749, valid loss 27968.9930
# Epoch 0043: train loss 31849.8473, valid loss 27658.3619
# Epoch 0044: train loss 31710.8812, valid loss 28249.7670
# Epoch 0045: train loss 31462.5733, valid loss 27599.9502
# Epoch 0046: train loss 31583.0622, valid loss 28409.9885
# Epoch 0047: train loss 31555.4413, valid loss 27749.3883
# Epoch 0048: train loss 30879.7734, valid loss 27498.2394
# Epoch 0049: train loss 31152.2558, valid loss 27639.0864
# Epoch 0050: train loss 30856.7948, valid loss 26940.9538
# Epoch 0051: train loss 30686.2795, valid loss 27141.2781
# Epoch 0052: train loss 30860.6328, valid loss 27117.0904
# Epoch 0053: train loss 30506.3244, valid loss 26760.0104
# Epoch 0054: train loss 32020.6103, valid loss 27821.3176
# Epoch 0055: train loss 30729.3116, valid loss 26125.5272
# Epoch 0056: train loss 30281.1682, valid loss 27097.2312
# Epoch 0057: train loss 30064.9015, valid loss 26313.0326
# Epoch 0058: train loss 30041.8743, valid loss 27281.9768
# Epoch 0059: train loss 30118.4746, valid loss 26865.2528
# Epoch 0060: train loss 30290.3883, valid loss 26412.4853
# Epoch 0061: train loss 30340.7899, valid loss 27411.6346
# Epoch 0062: train loss 28776.8170, valid loss 24862.0404
# Epoch 0063: train loss 28091.4716, valid loss 24551.6887
# Epoch 0064: train loss 27921.2968, valid loss 24431.5800
# Epoch 0065: train loss 27806.4829, valid loss 24388.2292
# Epoch 0066: train loss 27746.1987, valid loss 24297.2948
# Epoch 0067: train loss 27678.5399, valid loss 24242.9000
# Epoch 0068: train loss 27628.3204, valid loss 24171.1794
# Epoch 0069: train loss 27581.1933, valid loss 24163.9060
# Epoch 0070: train loss 27530.2045, valid loss 24168.8337
# Epoch 0071: train loss 27483.5331, valid loss 24084.5608
# Epoch 0072: train loss 27449.8656, valid loss 24147.1957
# Epoch 0073: train loss 27432.4086, valid loss 24017.1865
# Epoch 0074: train loss 27383.8367, valid loss 23962.0706
# Epoch 0075: train loss 27354.9120, valid loss 24004.4790
# Epoch 0076: train loss 27330.5000, valid loss 23949.2255
# Epoch 0077: train loss 27303.7304, valid loss 23960.9080
# Epoch 0078: train loss 27267.6925, valid loss 23914.0231
# Epoch 0079: train loss 27239.7346, valid loss 23826.9969
# Epoch 0080: train loss 27212.5833, valid loss 23836.3951
# Epoch 0081: train loss 27181.8192, valid loss 23813.2937
# Epoch 0082: train loss 27183.8746, valid loss 23836.6401
# Epoch 0083: train loss 27126.4676, valid loss 23766.1624
# Epoch 0084: train loss 27101.6510, valid loss 23721.9489
# Epoch 0085: train loss 27072.4740, valid loss 23724.9784
# Epoch 0086: train loss 27048.7737, valid loss 23662.9584
# Epoch 0087: train loss 27032.8372, valid loss 23667.0856
# Epoch 0088: train loss 26998.3589, valid loss 23629.2351
# Epoch 0089: train loss 26974.4867, valid loss 23692.3174
# Epoch 0090: train loss 26958.4852, valid loss 23638.8476
# Epoch 0091: train loss 26919.0691, valid loss 23626.8603
# Epoch 0092: train loss 26896.6943, valid loss 23575.2232
# Epoch 0093: train loss 26891.7661, valid loss 23551.2553
# Epoch 0094: train loss 26860.1992, valid loss 23529.3674
# Epoch 0095: train loss 26842.4518, valid loss 23549.9786
# Epoch 0096: train loss 26815.7406, valid loss 23531.1382
# Epoch 0097: train loss 26793.9431, valid loss 23495.3721
# Epoch 0098: train loss 26766.4102, valid loss 23491.5861
# Epoch 0099: train loss 26744.4470, valid loss 23517.9345
# Epoch 0100: train loss 26732.3562, valid loss 23449.0851
# Epoch 0101: train loss 26699.8847, valid loss 23376.4307
# Epoch 0102: train loss 26695.3250, valid loss 23373.7896
# Epoch 0103: train loss 26677.2500, valid loss 23428.2767
# Epoch 0104: train loss 26659.4941, valid loss 23403.6061
# Epoch 0105: train loss 26653.1924, valid loss 23332.7592
# Epoch 0106: train loss 26619.5991, valid loss 23310.9711
# Epoch 0107: train loss 26590.7004, valid loss 23324.9698
# Epoch 0108: train loss 26608.3366, valid loss 23306.6118
# Epoch 0109: train loss 26569.9529, valid loss 23263.7959
# Epoch 0110: train loss 26533.1086, valid loss 23292.6486
# Epoch 0111: train loss 26520.8014, valid loss 23319.4198
# Epoch 0112: train loss 26509.2617, valid loss 23215.9734
# Epoch 0113: train loss 26500.0192, valid loss 23196.0638
# Epoch 0114: train loss 26476.3201, valid loss 23243.3802
# Epoch 0115: train loss 26462.9885, valid loss 23230.0434
# Epoch 0116: train loss 26439.3822, valid loss 23155.9708
# Epoch 0117: train loss 26434.7666, valid loss 23140.9654
# Epoch 0118: train loss 26390.5332, valid loss 23114.8993
# Epoch 0119: train loss 26391.6883, valid loss 23187.6966
# Epoch 0120: train loss 26396.5415, valid loss 23124.7698
# Epoch 0121: train loss 26348.9662, valid loss 23043.4605
# Epoch 0122: train loss 26345.1066, valid loss 23121.2821
# Epoch 0123: train loss 26314.0715, valid loss 23085.6951
# Epoch 0124: train loss 26334.5427, valid loss 23095.5265
# Epoch 0125: train loss 26302.7588, valid loss 23008.8330
# Epoch 0126: train loss 26281.6738, valid loss 23035.6331
# Epoch 0127: train loss 26267.3806, valid loss 23029.5777
# Epoch 0128: train loss 26241.8321, valid loss 22956.0969
# Epoch 0129: train loss 26251.7092, valid loss 22965.2846
# Epoch 0130: train loss 26235.3654, valid loss 23005.4254
# Epoch 0131: train loss 26217.4524, valid loss 22942.7932
# Epoch 0132: train loss 26179.8040, valid loss 22980.5989
# Epoch 0133: train loss 26184.8870, valid loss 22932.8528
# Epoch 0134: train loss 26146.6283, valid loss 22909.5281
# Epoch 0135: train loss 26144.4664, valid loss 22837.9792
# Epoch 0136: train loss 26139.8319, valid loss 22904.8316
# Epoch 0137: train loss 26127.1643, valid loss 22866.5109
# Epoch 0138: train loss 26094.9130, valid loss 22864.0904
# Epoch 0139: train loss 26095.8172, valid loss 22843.3562
# Epoch 0140: train loss 26082.2598, valid loss 22914.5212
# Epoch 0141: train loss 26069.9140, valid loss 22842.5738
# Epoch 0142: train loss 25992.2150, valid loss 22734.1515
# Epoch 0143: train loss 25934.7937, valid loss 22709.4496
# Epoch 0144: train loss 25919.3900, valid loss 22713.0359
# Epoch 0145: train loss 25916.7982, valid loss 22723.3588
# Epoch 0146: train loss 25914.6472, valid loss 22735.5611
# Epoch 0147: train loss 25903.3029, valid loss 22725.2131
# Epoch 0148: train loss 25906.6911, valid loss 22700.4083
# Epoch 0149: train loss 25903.8948, valid loss 22699.2384
# Epoch 0150: train loss 25906.5085, valid loss 22675.9956
# Epoch 0151: train loss 25899.8089, valid loss 22694.7484
# Epoch 0152: train loss 25894.1520, valid loss 22701.7474
# Epoch 0153: train loss 25896.5050, valid loss 22684.1898
# Epoch 0154: train loss 25885.6081, valid loss 22686.9855
# Epoch 0155: train loss 25883.0848, valid loss 22728.7063
# Epoch 0156: train loss 25895.0389, valid loss 22700.7445
# Epoch 0157: train loss 25881.8584, valid loss 22698.9281
# Epoch 0158: train loss 25881.2322, valid loss 22686.5380
# Epoch 0159: train loss 25875.1985, valid loss 22677.7521
# Early stopping triggered
# Finished Training

# %% [markdown]
# # Evaluate

# %%
def interpret(model, data_loader, nodes_num, sampling_num=5, delay=5):
        model.eval()

        scores_sum = []
        outputs = []

        for (i,ts_batch) in enumerate(tqdm(data_loader)):
            ts_batch = ts_batch.to(device).type(torch.float32)
            x_hat, mean, log_var = model(ts_batch)

            sample_scores_sum = []

            for j in range(sampling_num):
                error_origin = torch.div((x_hat - ts_batch) ** 2, log_var.exp()) + log_var

                sample_score_sum = torch.sum(error_origin, 3)

                sample_scores_sum.append(sample_score_sum)

            score_sum = torch.mean(torch.stack(sample_scores_sum,3),3)
            #print(score_sum)

            scores_sum.append(score_sum.data.cpu().numpy())
            outputs.append(mean.data.cpu().numpy())

        scores_sum = np.concatenate(scores_sum)
        #print(scores_sum)
        outputs = np.concatenate(outputs)

        scores_argsort = np.argsort(-scores_sum)

        return scores_sum, outputs, scores_argsort

# %%
scores_sum, outputs, scores_argsort = interpret(model, test_loader, NUM_OF_COMPONENTS)

# %%
def interpret_lstm(model, data_loader, nodes_num, sampling_num=5, delay=5):
    model.eval()

    scores_sum = []
    outputs = []

    for (i, ts_batch) in enumerate(tqdm(data_loader)):
        ts_batch = ts_batch.to(device).type(torch.float32)
        x_hat, mean, log_var = model(ts_batch)

        # Infer shape details
        batch_size, seq_len, input_dim = ts_batch.shape
        num_metrics = input_dim // nodes_num

        ts_batch = ts_batch.view(batch_size, seq_len, nodes_num, num_metrics)
        x_hat = x_hat.view(batch_size, seq_len, nodes_num, num_metrics)

        sample_scores_sum = []

        for j in range(sampling_num):
            # Use plain squared error for now
            error_origin = (x_hat - ts_batch) ** 2
            sample_score_sum = torch.sum(error_origin, dim=3)  # sum over nodes/hosts
            sample_scores_sum.append(sample_score_sum)

        score_sum = torch.mean(torch.stack(sample_scores_sum, dim=3), dim=3)
        scores_sum.append(score_sum.data.cpu().numpy())
        outputs.append(mean.data.cpu().numpy())

    scores_sum = np.concatenate(scores_sum)
    outputs = np.concatenate(outputs)
    scores_argsort = np.argsort(-scores_sum)

    return scores_sum, outputs, scores_argsort

# %%
scores_sum, outputs, scores_argsort = interpret_lstm(model, test_loader, NUM_OF_COMPONENTS, 26)
# Out:
# 100%|██████████| 41/41 [00:00<00:00, 227.04it/s]

# %%
threshold = np.percentile(scores_sum, 95)
anomalies = scores_sum > threshold

print("Anomaly Indices:", np.where(anomalies)[0])
# Out:
# Anomaly Indices: [   0    0    0 ... 1291 1291 1291]

# %%
print(threshold)
# Out:
# 13.4350395

# %%
print(len(np.where(anomalies)[0]))
# Out:
# 9690

# %%
print(len(scores_sum))
# Out:
# 1292

# %%
# Create a binary array with the same length as true_anomalies
predicted_anomalies = np.zeros_like(true_anomalies, dtype=bool)

# Flatten anomalies to match the shape of predicted_anomalies
flattened_anomalies = anomalies.any(axis=(1, 2)) #Checks for any anomaly across components and timestamps for each sequence in test_data

# Create anomaly_indices to match true_anomalies length
anomaly_indices = np.arange(len(true_anomalies))
anomaly_indices = anomaly_indices[metric.shape[0] - len(sequences): metric.shape[0] - len(sequences) + len(flattened_anomalies)]

# Reshape anomalies to have a single column
reshaped_anomalies = flattened_anomalies.reshape(-1, 1)

# Now assign the anomaly values (True/False) using boolean indexing
predicted_anomalies[anomaly_indices] = reshaped_anomalies

# Calculate the F1 score
f1 = f1_score(true_anomalies, predicted_anomalies)

print(f"F1 Score: {f1}")
# Out:
# F1 Score: 0.06275902901124926

# %%
reference_f1 = 0.481

plt.figure(figsize=(8, 6))
bars = plt.bar(['Reference F1', 'Calculated F1'], [reference_f1, f1])

plt.ylabel('F1 Score')
plt.title('Comparison of F1 Scores')

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 3), ha='center', va='bottom')

plt.show()

# %%
print(classification_report(true_anomalies, predicted_anomalies))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90      8074
#            1       0.05      0.09      0.06       566
#
#     accuracy                           0.82      8640
#    macro avg       0.49      0.48      0.48      8640
# weighted avg       0.87      0.82      0.84      8640

# %%
print(confusion_matrix(true_anomalies, predicted_anomalies))
# Out:
# [[7004 1070]
#  [ 513   53]]
